# %%
#Q1 
import numpy as np
import pandas as pd
data={'name':["rishi","rj","rk"],'age':[21,21,21],'mailid':["rishikemni@gmail.com","123@gmail.com","rishi@gmail.com"],'ph':[8888777790,9416274517,9729024723]}
df=pd.DataFrame(data)
print(df)
# Out:
#     name  age                mailid          ph
# 0  rishi   21  rishikemni@gmail.com  8888777790
# 1     rj   21         123@gmail.com  9416274517
# 2     rk   21       rishi@gmail.com  9729024723

# %%
data={'name':["rishi","rj","rk"],'age':[21,21,21],'mailid':["rishikemni@gmail.com","123@gmail.com","rishi@gmail.com"],'ph':[8888777790,9416274517,9729024723]}
df=pd.DataFrame(data,index=["t","tt","ttt"])
print(df)
# Out:
#       name  age                mailid          ph
# t    rishi   21  rishikemni@gmail.com  8888777790
# tt      rj   21         123@gmail.com  9416274517
# ttt     rk   21       rishi@gmail.com  9729024723

# %%
#Q2
import pandas as pd
df = pd.read_csv('weather.csv')
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.head(10)
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   1/1/2016           38        23        52                 30.03
# 1   1/2/2016           36        18        46                 30.02
# 2   1/3/2016           40        21        47                 29.86
# 3   1/4/2016           25         9        44                 30.05
# 4   1/5/2016           20        -3        41                 30.57
# 5   1/6/2016           33         4        35                 30.50
# 6   1/7/2016           39        11        33                 30.28
# 7   1/8/2016           39        29        64                 30.20
# 8   1/9/2016           44        38        77                 30.16
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# ...

# %%
#basic Stats
df['WindSpeedMPH'].describe()
# Out:
# count    28.000000
# mean      6.892857
# std       2.871821
# min       2.000000
# 25%       5.000000
# 50%       6.500000
# 75%       8.000000
# max      16.000000
# Name: WindSpeedMPH, dtype: float64

# %%
df.tail()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
# Extract the 2nd column and find basic statistics on it.
df['Temperature'].describe(include='all')
# Out:
# count    31.000000
# mean     34.677419
# std       7.639315
# min      20.000000
# 25%      29.000000
# 50%      35.000000
# 75%      39.500000
# max      50.000000
# Name: Temperature, dtype: float64
